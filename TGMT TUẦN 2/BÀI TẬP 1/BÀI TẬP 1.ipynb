# %%
from PIL import Image

# %%
dir = 'C:/Users/Acer/Pictures'

# %%
image_path = dir +'/1.PNG'

# %%
print(image_path)
# Out:
# C:/Users/Acer/Pictures/1.PNG

# %%
img01 = Image.open(image_path)

# %%
display(img01)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=684x690>

# %%
print("Định dang ảnh: ", img01.format)
# Out:
# Định dang ảnh:  PNG

# %%
print("Kích thước hình ảnh: ", img01.size)
# Out:
# Kích thước hình ảnh:  (684, 690)

# %%
img01_rgb = img01.convert('RGB')

# %%
new_img_01_path = dir + '/new_1.PNG'
new_img_jpg_01_path = dir + '/new_1.JPG'
img01_rgb.save(new_img_01_path)
img01_rgb.save(new_img_jpg_01_path)

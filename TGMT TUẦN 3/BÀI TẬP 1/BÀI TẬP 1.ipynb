# %%
from PIL import Image
from imgtools import *
from IPython.display import display

# %%
dir = 'C:/Users/Acer/Pictures'

# %%
img_path = dir + '/Capture1.PNG'

# %%
print(img_path)
# Out:
# C:/Users/Acer/Pictures/Capture1.PNG

# %%
img = Image.open(img_path)

# %%
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x1080>

# %%
print(img.size)
# Out:
# (1920, 1080)

# %%
new_size = (100,100)

# %%
new_image = img.resize(new_size)

# %%
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=100x100>

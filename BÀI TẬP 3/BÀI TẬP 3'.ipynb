# %%
from PIL import Image
from imgtools import *
from IPython.display import display # to display images

# %%
dir = 'C:/Users/Acer/Pictures'

# %%
image_path = dir +'/211.PNG'

# %%
print(image_path)
# Out:
# C:/Users/Acer/Pictures/211.PNG

# %%
img01 = Image.open(image_path)

# %%
display(img01)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x1080>

# %%
new_size = (1000,1000)
new_image = img01.resize(new_size)
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=1000x1000>

# %%
thumbnail_size = (50,50)
img01.thumbnail(thumbnail_size)
display(img01)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=50x28>
